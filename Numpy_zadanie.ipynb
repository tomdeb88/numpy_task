# %% [markdown]
# # Ile będzie wynosiła orientacyjna cena mieszkania za 5 lat?
# - 154003.04

# %%
import numpy as np 
import numpy_financial as npf
import matplotlib.pyplot as plt



a=np.arange(1,61)
capital_needed=np.round(npf.fv(0.05/12,a,0,-120000),2)
capital_needed
# Out:
# array([120500.  , 121002.08, 121506.26, 122012.53, 122520.92, 123031.42,
#        123544.06, 124058.82, 124575.73, 125094.8 , 125616.03, 126139.43,
#        126665.01, 127192.78, 127722.75, 128254.93, 128789.32, 129325.95,
#        129864.8 , 130405.91, 130949.26, 131494.89, 132042.78, 132592.96,
#        133145.43, 133700.2 , 134257.29, 134816.69, 135378.43, 135942.51,
#        136508.93, 137077.72, 137648.88, 138222.41, 138798.34, 139376.67,
#        139957.4 , 140540.56, 141126.15, 141714.17, 142304.65, 142897.58,
#        143492.99, 144090.88, 144691.26, 145294.14, 145899.53, 146507.44,
#        147117.89, 147730.88, 148346.43, 148964.54, 149585.22, 150208.49,
#        150834.36, 151462.84, 152093.93, 152727.66, 153364.02, 154003.04])

# %% [markdown]
# # Ile musisz wpłacać do banku każdego miesiąca, aby przy przedstawionej ofercie uzbierać na mieszkanie w ciągu 5 lat?
# -1952.08

# %%
b=np.ones(12)
np.around(npf.ipmt(0.12/12,12,b*5,154003),2)
# Out:
# array([1952.08, 1952.08, 1952.08, 1952.08, 1952.08, 1952.08, 1952.08,
#        1952.08, 1952.08, 1952.08, 1952.08, 1952.08])

# %% [markdown]
# # Stwórz wykres przedstawiający, jak w interwałach miesięcznych zmieniać się będzie cena mieszkania (liniowy wzrost w całym okresie) oraz wartość twojej lokaty.

# %%
c=np.arange(1,61)
capital= np.round(npf.fv(0.12/12,c,-1952.08,0),2)
capital
# Out:
# array([  1952.08,   3923.68,   5915.  ,   7926.23,   9957.57,  12009.23,
#         14081.4 ,  16174.29,  18288.11,  20423.08,  22579.39,  24757.26,
#         26956.91,  29178.56,  31422.43,  33688.73,  35977.7 ,  38289.56,
#         40624.53,  42982.86,  45364.77,  47770.49,  50200.28,  52654.36,
#         55132.98,  57636.39,  60164.84,  62718.57,  65297.83,  67902.89,
#         70534.  ,  73191.42,  75875.41,  78586.25,  81324.19,  84089.51,
#         86882.49,  89703.39,  92552.51,  95430.11,  98336.49, 101271.94,
#        104236.74, 107231.18, 110255.58, 113310.21, 116395.39, 119511.43,
#        122658.62, 125837.29, 129047.74, 132290.3 , 135565.28, 138873.01,
#        142213.82, 145588.04, 148996.  , 152438.04, 155914.5 , 159425.73])

# %%
plt.plot(capital_needed,label='kpotrzebny')
plt.plot(capital,label='oszczednosci')
plt.legend()
plt.xlabel('czas')
plt.ylabel('$')
# Out:
# Text(0, 0.5, '$')
